# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 4])
print(s)
print(type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#Indexing 
print(s[0])
print(s[2])
# Out:
# 1
# 3
