# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 4])
print(s)
print(type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#Indexing 
print(s[0])
print(s[2])
# Out:
# 1
# 3

# %%
# Label 
s = pd.Series([20, 25, 22, 24], index=["Adam", "Bob", "Eve", "Charlie"])
print(s)
# Out:
# Adam       20
# Bob        25
# Eve        22
# Charlie    24
# dtype: int64
