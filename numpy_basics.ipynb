# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40])
print(arr, type(arr))
# Out:
# [10 20 30 40] <class 'numpy.ndarray'>

# %%
# python list vs NumPy array : 

#1. NumPy arraya are faster(optimized in c)
#2. NumPy stores data in continous memory blocks
#3. uses less memory(optimized storage)
#4. built-in  mathametical functions
#5. supports direct vectorized operations

# %%
# so why is NumPy is faster ?

#. Homogeneous data types and contigous memory
#. vector operations & c implementations
#. Reduce overhead

# %%
# we can even print the shape total number of elemts :

print(arr.shape)
# Out:
# (4,)
